# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %% [markdown]
# ## Retreiving the Nearest City

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 786

# %% [markdown]
# ## Performing an API Call with the OpenWeatherMap

# %%
#Import dependencies
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nicolet
# Processing Record 2 of Set 1 | hithadhoo
# Processing Record 3 of Set 1 | udala
# Processing Record 4 of Set 1 | inhambane
# Processing Record 5 of Set 1 | westport
# Processing Record 6 of Set 1 | ulaanbaatar
# Processing Record 7 of Set 1 | saldanha
# Processing Record 8 of Set 1 | san antonio
# Processing Record 9 of Set 1 | new norfolk
# Processing Record 10 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 1 | port alfred
# Processing Record 12 of Set 1 | castro
# Processing Record 13 of Set 1 | ouesso
# Processing Record 14 of Set 1 | ahipara
# Processing Record 15 of Set 1 | burewala
# Processing Record 16 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 17 of Set 1 | chapais
# Processing Record 18 of Set 1 | menomonie
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | kurumkan
# Processing Record 21 of Set 1 | pisco
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | quchan
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | avarua
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | tasiilaq
# Processing Record 28 of Set 1 | thai binh
# Processing Record 29 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 1 | shimoda
# Processing Record 31 of Set 1 | ponta do sol
# Processing Record 32 of Set 1 | khatanga
# Processing Record 33 of Set 1 | airai
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | ugoofaaru
# Processing Record 36 of Set 1 | albany
# Processing Record 37 of Set 1 | busselton
# Processing Record 38 of Set 1 | cape town
# Processing Record 39 of Set 1 | hit
# Processing Record 40 of Set 1 | butaritari
# Processing Record 41 of Set 1 | urucara
# Processing Record 42 of Set 1 | mar del plata
# Processing Record 43 of Set 1 | roebourne
# Processing Record 44 of Set 1 | thompson
# Processing Record 45 of Set 1 | bredasdorp
# Processing Record 46 of Set 1 | georgetown
# Processing Record 47 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 1 | emerald
# Processing Record 49 of Set 1 | itarema
# Processing Record 50 of Set 1 | comodoro rivadavia
# Processing Record 1 of Set 2 | tiksi
# Processing Record 2 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 3 of Set 2 | puerto del rosario
# Processing Record 4 of Set 2 | east london
# Processing Record 5 of Set 2 | usinsk
# Processing Record 6 of Set 2 | luorong
# Processing Record 7 of Set 2 | talnakh
# Processing Record 8 of Set 2 | kavieng
# Processing Record 9 of Set 2 | yellowknife
# Processing Record 10 of Set 2 | nyurba
# Processing Record 11 of Set 2 | katangli
# Processing Record 12 of Set 2 | coquimbo
# Processing Record 13 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 2 | longyearbyen
# Processing Record 15 of Set 2 | bluff
# Processing Record 16 of Set 2 | nome
# Processing Record 17 of Set 2 | hobart
# Processing Record 18 of Set 2 | kuytun
# Processing Record 19 of Set 2 | huarmey
# Processing Record 20 of Set 2 | torbay
# Processing Record 21 of Set 2 | olafsvik
# Processing Record 22 of Set 2 | namatanai
# Processing Record 23 of Set 2 | attingal
# Processing Record 24 of Set 2 | port elizabeth
# Processing Record 25 of Set 2 | jamestown
# Processing Record 26 of Set 2 | souillac
# Processing Record 27 of Set 2 | hendijan
# City not found. Skipping...
# Processing Record 28 of Set 2 | tura
# Processing Record 29 of Set 2 | rawson
# Processing Record 30 of Set 2 | beidao
# Processing Record 31 of Set 2 | agadez
# Processing Record 32 of Set 2 | lodja
# Processing Record 33 of Set 2 | cumana
# Processing Record 34 of Set 2 | markova
# Processing Record 35 of Set 2 | bethel
# Processing Record 36 of Set 2 | bagarji
# Processing Record 37 of Set 2 | arraial do cabo
# Processing Record 38 of Set 2 | barrow
# Processing Record 39 of Set 2 | boa vista
# Processing Record 40 of Set 2 | vaini
# Processing Record 41 of Set 2 | saint-philippe
# Processing Record 42 of Set 2 | tual
# Processing Record 43 of Set 2 | carnarvon
# Processing Record 44 of Set 2 | bambous virieux
# Processing Record 45 of Set 2 | meulaboh
# Processing Record 46 of Set 2 | kavaratti
# Processing Record 47 of Set 2 | verkh-usugli
# Processing Record 48 of Set 2 | springdale
# Processing Record 49 of Set 2 | kathmandu
# Processing Record 50 of Set 2 | atuona
# Processing Record 1 of Set 3 | channel-port aux basques
# Processing Record 2 of Set 3 | one hundred mile house
# City not found. Skipping...
# Processing Record 3 of Set 3 | petauke
# Processing Record 4 of Set 3 | vostok
# Processing Record 5 of Set 3 | qaanaaq
# Processing Record 6 of Set 3 | provideniya
# Processing Record 7 of Set 3 | dolbeau
# City not found. Skipping...
# Processing Record 8 of Set 3 | lebu
# Processing Record 9 of Set 3 | atambua
# Processing Record 10 of Set 3 | port hardy
# Processing Record 11 of Set 3 | hamilton
# Processing Record 12 of Set 3 | skegness
# Processing Record 13 of Set 3 | chernyshevskiy
# Processing Record 14 of Set 3 | ust-kuyga
# Processing Record 15 of Set 3 | byron bay
# Processing Record 16 of Set 3 | lavrentiya
# Processing Record 17 of Set 3 | taywarah
# Processing Record 18 of Set 3 | garissa
# Processing Record 19 of Set 3 | fomboni
# Processing Record 20 of Set 3 | hasaki
# Processing Record 21 of Set 3 | dicabisagan
# Processing Record 22 of Set 3 | joshimath
# Processing Record 23 of Set 3 | dunedin
# Processing Record 24 of Set 3 | waipawa
# Processing Record 25 of Set 3 | bengkulu
# Processing Record 26 of Set 3 | babanusah
# City not found. Skipping...
# Processing Record 27 of Set 3 | lazaro cardenas
# Processing Record 28 of Set 3 | lompoc
# Processing Record 29 of Set 3 | lebork
# Processing Record 30 of Set 3 | pout
# Processing Record 31 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 32 of Set 3 | russell
# Processing Record 33 of Set 3 | punta arenas
# Processing Record 34 of Set 3 | surt
# Processing Record 35 of Set 3 | caravelas
# Processing Record 36 of Set 3 | desterro
# Processing Record 37 of Set 3 | la victoria
# Processing Record 38 of Set 3 | ribeira grande
# Processing Record 39 of Set 3 | muros
# Processing Record 40 of Set 3 | chara
# Processing Record 41 of Set 3 | puerto ayora
# Processing Record 42 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 3 | sainte-anne-des-monts
# Processing Record 44 of Set 3 | simontornya
# Processing Record 45 of Set 3 | aykhal
# Processing Record 46 of Set 3 | cabo san lucas
# Processing Record 47 of Set 3 | amahai
# Processing Record 48 of Set 3 | chuy
# Processing Record 49 of Set 3 | lumby
# Processing Record 50 of Set 3 | half moon bay
# Processing Record 1 of Set 4 | kruisfontein
# Processing Record 2 of Set 4 | portobelo
# Processing Record 3 of Set 4 | gueugnon
# Processing Record 4 of Set 4 | alamogordo
# Processing Record 5 of Set 4 | san roque
# Processing Record 6 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 4 | zapolyarnyy
# Processing Record 8 of Set 4 | magdagachi
# Processing Record 9 of Set 4 | faanui
# Processing Record 10 of Set 4 | tuatapere
# Processing Record 11 of Set 4 | smithers
# Processing Record 12 of Set 4 | alenquer
# Processing Record 13 of Set 4 | zhigalovo
# Processing Record 14 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 4 | dubbo
# Processing Record 16 of Set 4 | missouri city
# Processing Record 17 of Set 4 | solano
# Processing Record 18 of Set 4 | dukat
# Processing Record 19 of Set 4 | kaitangata
# Processing Record 20 of Set 4 | tommot
# Processing Record 21 of Set 4 | thilogne
# City not found. Skipping...
# Processing Record 22 of Set 4 | caborca
# Processing Record 23 of Set 4 | davidson
# Processing Record 24 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 4 | aberystwyth
# Processing Record 26 of Set 4 | neiba
# Processing Record 27 of Set 4 | yichang
# Processing Record 28 of Set 4 | neiafu
# Processing Record 29 of Set 4 | saint-joseph
# Processing Record 30 of Set 4 | mount gambier
# Processing Record 31 of Set 4 | pujili
# Processing Record 32 of Set 4 | mehamn
# Processing Record 33 of Set 4 | taunsa
# Processing Record 34 of Set 4 | akrini
# Processing Record 35 of Set 4 | jedrzejow
# Processing Record 36 of Set 4 | seoul
# Processing Record 37 of Set 4 | mountain home
# Processing Record 38 of Set 4 | maxixe
# Processing Record 39 of Set 4 | saint george
# Processing Record 40 of Set 4 | kapaa
# Processing Record 41 of Set 4 | columbus
# Processing Record 42 of Set 4 | ilulissat
# Processing Record 43 of Set 4 | upernavik
# Processing Record 44 of Set 4 | kutum
# Processing Record 45 of Set 4 | kodiak
# Processing Record 46 of Set 4 | vaitape
# Processing Record 47 of Set 4 | ponta delgada
# Processing Record 48 of Set 4 | hegra
# Processing Record 49 of Set 4 | ogbomosho
# Processing Record 50 of Set 4 | drayton valley
# Processing Record 1 of Set 5 | tselinnoye
# Processing Record 2 of Set 5 | ostrovnoy
# Processing Record 3 of Set 5 | tokmak
# Processing Record 4 of Set 5 | naftah
# City not found. Skipping...
# Processing Record 5 of Set 5 | saskylakh
# Processing Record 6 of Set 5 | yumen
# Processing Record 7 of Set 5 | tuktoyaktuk
# Processing Record 8 of Set 5 | dalhousie
# Processing Record 9 of Set 5 | clyde river
# Processing Record 10 of Set 5 | praya
# Processing Record 11 of Set 5 | victoria
# Processing Record 12 of Set 5 | bani
# Processing Record 13 of Set 5 | mahebourg
# Processing Record 14 of Set 5 | yangshe
# Processing Record 15 of Set 5 | cidreira
# Processing Record 16 of Set 5 | bantva
# Processing Record 17 of Set 5 | pevek
# Processing Record 18 of Set 5 | baherden
# Processing Record 19 of Set 5 | orlik
# Processing Record 20 of Set 5 | kahului
# Processing Record 21 of Set 5 | sapao
# City not found. Skipping...
# Processing Record 22 of Set 5 | marivan
# Processing Record 23 of Set 5 | nikolskoye
# Processing Record 24 of Set 5 | morelia
# Processing Record 25 of Set 5 | bilibino
# Processing Record 26 of Set 5 | pamekasan
# Processing Record 27 of Set 5 | upata
# Processing Record 28 of Set 5 | gondanglegi
# Processing Record 29 of Set 5 | san patricio
# Processing Record 30 of Set 5 | manitouwadge
# Processing Record 31 of Set 5 | sinnamary
# Processing Record 32 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 5 | ostersund
# Processing Record 34 of Set 5 | dzilam gonzalez
# Processing Record 35 of Set 5 | erenhot
# Processing Record 36 of Set 5 | lourical
# Processing Record 37 of Set 5 | tabialan
# City not found. Skipping...
# Processing Record 38 of Set 5 | bondoukou
# Processing Record 39 of Set 5 | whitehorse
# Processing Record 40 of Set 5 | narsaq
# Processing Record 41 of Set 5 | walvis bay
# Processing Record 42 of Set 5 | novobirilyussy
# Processing Record 43 of Set 5 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 44 of Set 5 | norman wells
# Processing Record 45 of Set 5 | saint-pierre
# Processing Record 46 of Set 5 | sobolevo
# Processing Record 47 of Set 5 | mizque
# Processing Record 48 of Set 5 | tamiahua
# Processing Record 49 of Set 5 | asau
# Processing Record 50 of Set 5 | sisimiut
# Processing Record 1 of Set 6 | alamos
# Processing Record 2 of Set 6 | nanlong
# Processing Record 3 of Set 6 | darfo
# Processing Record 4 of Set 6 | aripuana
# Processing Record 5 of Set 6 | pestovo
# Processing Record 6 of Set 6 | kuito
# Processing Record 7 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 6 | green river
# Processing Record 9 of Set 6 | santona
# Processing Record 10 of Set 6 | salalah
# Processing Record 11 of Set 6 | hohhot
# Processing Record 12 of Set 6 | kolpashevo
# Processing Record 13 of Set 6 | tarakan
# Processing Record 14 of Set 6 | karamken
# City not found. Skipping...
# Processing Record 15 of Set 6 | gat
# Processing Record 16 of Set 6 | minab
# Processing Record 17 of Set 6 | batagay-alyta
# Processing Record 18 of Set 6 | ganzhou
# Processing Record 19 of Set 6 | esperance
# Processing Record 20 of Set 6 | marsh harbour
# Processing Record 21 of Set 6 | cedar city
# Processing Record 22 of Set 6 | severo-kurilsk
# Processing Record 23 of Set 6 | iquique
# Processing Record 24 of Set 6 | komsomolskiy
# Processing Record 25 of Set 6 | jining
# Processing Record 26 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 27 of Set 6 | vysokogornyy
# Processing Record 28 of Set 6 | fortuna
# Processing Record 29 of Set 6 | ranong
# Processing Record 30 of Set 6 | tanda
# Processing Record 31 of Set 6 | billings
# Processing Record 32 of Set 6 | fiumicino
# Processing Record 33 of Set 6 | brownsville
# Processing Record 34 of Set 6 | sungaipenuh
# Processing Record 35 of Set 6 | lorengau
# Processing Record 36 of Set 6 | aswan
# Processing Record 37 of Set 6 | asfi
# Processing Record 38 of Set 6 | kologriv
# Processing Record 39 of Set 6 | havre-saint-pierre
# Processing Record 40 of Set 6 | oistins
# Processing Record 41 of Set 6 | yulara
# Processing Record 42 of Set 6 | touros
# Processing Record 43 of Set 6 | hare bay
# Processing Record 44 of Set 6 | vao
# Processing Record 45 of Set 6 | dikson
# Processing Record 46 of Set 6 | vallenar
# Processing Record 47 of Set 6 | sri aman
# Processing Record 48 of Set 6 | broome
# Processing Record 49 of Set 6 | colares
# Processing Record 50 of Set 6 | topolobampo
# Processing Record 1 of Set 7 | port lincoln
# Processing Record 2 of Set 7 | namwala
# Processing Record 3 of Set 7 | maceio
# Processing Record 4 of Set 7 | turukhansk
# Processing Record 5 of Set 7 | eisenerz
# Processing Record 6 of Set 7 | korsakov
# Processing Record 7 of Set 7 | roswell
# Processing Record 8 of Set 7 | ligayan
# Processing Record 9 of Set 7 | bereda
# Processing Record 10 of Set 7 | sitka
# Processing Record 11 of Set 7 | aklavik
# Processing Record 12 of Set 7 | leicester
# Processing Record 13 of Set 7 | raton
# Processing Record 14 of Set 7 | isangel
# Processing Record 15 of Set 7 | road town
# Processing Record 16 of Set 7 | lao cai
# Processing Record 17 of Set 7 | grindavik
# Processing Record 18 of Set 7 | houma
# Processing Record 19 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 7 | coahuayana
# Processing Record 21 of Set 7 | fairbanks
# Processing Record 22 of Set 7 | goderich
# Processing Record 23 of Set 7 | metro
# Processing Record 24 of Set 7 | mecca
# Processing Record 25 of Set 7 | dalvik
# Processing Record 26 of Set 7 | bonthe
# Processing Record 27 of Set 7 | gradsko
# Processing Record 28 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 29 of Set 7 | bacolod
# Processing Record 30 of Set 7 | san cristobal
# Processing Record 31 of Set 7 | mandalgovi
# Processing Record 32 of Set 7 | jieshi
# Processing Record 33 of Set 7 | jinchang
# Processing Record 34 of Set 7 | bajo baudo
# City not found. Skipping...
# Processing Record 35 of Set 7 | vrede
# Processing Record 36 of Set 7 | luderitz
# Processing Record 37 of Set 7 | iqaluit
# Processing Record 38 of Set 7 | port macquarie
# Processing Record 39 of Set 7 | mayuge
# Processing Record 40 of Set 7 | kiama
# Processing Record 41 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 7 | pokhara
# Processing Record 43 of Set 7 | isla vista
# Processing Record 44 of Set 7 | belyy yar
# Processing Record 45 of Set 7 | vila franca do campo
# Processing Record 46 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 47 of Set 7 | aden
# Processing Record 48 of Set 7 | maneadero
# Processing Record 49 of Set 7 | te anau
# Processing Record 50 of Set 7 | sept-iles
# Processing Record 1 of Set 8 | fort nelson
# Processing Record 2 of Set 8 | destin
# Processing Record 3 of Set 8 | moree
# Processing Record 4 of Set 8 | roma
# Processing Record 5 of Set 8 | bahia blanca
# Processing Record 6 of Set 8 | cairns
# Processing Record 7 of Set 8 | college
# Processing Record 8 of Set 8 | kisangani
# Processing Record 9 of Set 8 | sarangani
# Processing Record 10 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 11 of Set 8 | mafeteng
# Processing Record 12 of Set 8 | kaka
# Processing Record 13 of Set 8 | toamasina
# Processing Record 14 of Set 8 | sechura
# Processing Record 15 of Set 8 | monrovia
# Processing Record 16 of Set 8 | kisesa
# Processing Record 17 of Set 8 | santa cruz
# Processing Record 18 of Set 8 | isla mujeres
# Processing Record 19 of Set 8 | pedasi
# Processing Record 20 of Set 8 | sao filipe
# Processing Record 21 of Set 8 | sabang
# Processing Record 22 of Set 8 | marmashen
# Processing Record 23 of Set 8 | formosa
# Processing Record 24 of Set 8 | lushunkou
# City not found. Skipping...
# Processing Record 25 of Set 8 | beringovskiy
# Processing Record 26 of Set 8 | kalabo
# Processing Record 27 of Set 8 | new ulm
# Processing Record 28 of Set 8 | lampa
# Processing Record 29 of Set 8 | lubao
# Processing Record 30 of Set 8 | ulladulla
# Processing Record 31 of Set 8 | santa cruz de la palma
# Processing Record 32 of Set 8 | chokurdakh
# Processing Record 33 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 8 | acapulco
# Processing Record 35 of Set 8 | bystryy istok
# Processing Record 36 of Set 8 | matagami
# Processing Record 37 of Set 8 | humboldt
# Processing Record 38 of Set 8 | srednekolymsk
# Processing Record 39 of Set 8 | nuuk
# Processing Record 40 of Set 8 | rincon
# Processing Record 41 of Set 8 | galgani
# City not found. Skipping...
# Processing Record 42 of Set 8 | cassilandia
# Processing Record 43 of Set 8 | umm lajj
# Processing Record 44 of Set 8 | nishihara
# Processing Record 45 of Set 8 | dwarka
# Processing Record 46 of Set 8 | mayo
# Processing Record 47 of Set 8 | gander
# Processing Record 48 of Set 8 | brookhaven
# Processing Record 49 of Set 8 | college place
# Processing Record 50 of Set 8 | pangai
# Processing Record 1 of Set 9 | dryden
# Processing Record 2 of Set 9 | mabaruma
# Processing Record 3 of Set 9 | mumford
# Processing Record 4 of Set 9 | hambantota
# Processing Record 5 of Set 9 | ixtapa
# Processing Record 6 of Set 9 | luebo
# Processing Record 7 of Set 9 | rosetta
# Processing Record 8 of Set 9 | yarmouth
# Processing Record 9 of Set 9 | yerbogachen
# Processing Record 10 of Set 9 | krasnoselkup
# Processing Record 11 of Set 9 | port blair
# Processing Record 12 of Set 9 | makakilo city
# Processing Record 13 of Set 9 | sholapur
# Processing Record 14 of Set 9 | mount isa
# Processing Record 15 of Set 9 | gamba
# Processing Record 16 of Set 9 | zagreb
# Processing Record 17 of Set 9 | mudon
# Processing Record 18 of Set 9 | guerrero negro
# Processing Record 19 of Set 9 | qeshm
# Processing Record 20 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 21 of Set 9 | churapcha
# Processing Record 22 of Set 9 | hobyo
# Processing Record 23 of Set 9 | bolobo
# Processing Record 24 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 25 of Set 9 | kingsport
# Processing Record 26 of Set 9 | ambilobe
# Processing Record 27 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 28 of Set 9 | muscat
# Processing Record 29 of Set 9 | kalmunai
# Processing Record 30 of Set 9 | rocha
# Processing Record 31 of Set 9 | lingao
# Processing Record 32 of Set 9 | nurota
# Processing Record 33 of Set 9 | kysyl-syr
# Processing Record 34 of Set 9 | lashio
# Processing Record 35 of Set 9 | pointe michel
# Processing Record 36 of Set 9 | andenes
# Processing Record 37 of Set 9 | kayerkan
# Processing Record 38 of Set 9 | langsa
# Processing Record 39 of Set 9 | ladario
# Processing Record 40 of Set 9 | avera
# Processing Record 41 of Set 9 | poum
# Processing Record 42 of Set 9 | labuhan
# Processing Record 43 of Set 9 | natal
# Processing Record 44 of Set 9 | manzhouli
# Processing Record 45 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 46 of Set 9 | phrai bung
# City not found. Skipping...
# Processing Record 47 of Set 9 | garowe
# Processing Record 48 of Set 9 | luanda
# Processing Record 49 of Set 9 | dawson creek
# Processing Record 50 of Set 9 | yambio
# Processing Record 1 of Set 10 | mahibadhoo
# Processing Record 2 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 3 of Set 10 | enumclaw
# Processing Record 4 of Set 10 | antibes
# Processing Record 5 of Set 10 | wakkanai
# Processing Record 6 of Set 10 | santa rosa
# Processing Record 7 of Set 10 | bom jesus da lapa
# Processing Record 8 of Set 10 | lata
# Processing Record 9 of Set 10 | raudeberg
# Processing Record 10 of Set 10 | vanimo
# Processing Record 11 of Set 10 | ndele
# Processing Record 12 of Set 10 | dongsheng
# Processing Record 13 of Set 10 | belfast
# Processing Record 14 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 15 of Set 10 | siderno
# Processing Record 16 of Set 10 | matam
# Processing Record 17 of Set 10 | marrakesh
# Processing Record 18 of Set 10 | la rioja
# Processing Record 19 of Set 10 | salinopolis
# Processing Record 20 of Set 10 | constitucion
# Processing Record 21 of Set 10 | kirkwall
# Processing Record 22 of Set 10 | port hawkesbury
# Processing Record 23 of Set 10 | zhangye
# Processing Record 24 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 10 | perelyub
# Processing Record 26 of Set 10 | duncan
# Processing Record 27 of Set 10 | puteyets
# Processing Record 28 of Set 10 | sao joao do paraiso
# Processing Record 29 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 30 of Set 10 | spirovo
# Processing Record 31 of Set 10 | todos santos
# Processing Record 32 of Set 10 | ancud
# Processing Record 33 of Set 10 | klaksvik
# Processing Record 34 of Set 10 | suez
# Processing Record 35 of Set 10 | birao
# Processing Record 36 of Set 10 | dolores
# Processing Record 37 of Set 10 | polis
# Processing Record 38 of Set 10 | akureyri
# Processing Record 39 of Set 10 | marsa matruh
# Processing Record 40 of Set 10 | marzuq
# Processing Record 41 of Set 10 | vredendal
# Processing Record 42 of Set 10 | eldorado
# Processing Record 43 of Set 10 | hailey
# Processing Record 44 of Set 10 | bogo
# Processing Record 45 of Set 10 | katherine
# Processing Record 46 of Set 10 | linguere
# Processing Record 47 of Set 10 | pierre
# Processing Record 48 of Set 10 | mapiripan
# Processing Record 49 of Set 10 | kaeo
# Processing Record 50 of Set 10 | quatre cocos
# Processing Record 1 of Set 11 | boyuibe
# Processing Record 2 of Set 11 | korla
# Processing Record 3 of Set 11 | lalibela
# Processing Record 4 of Set 11 | alyangula
# Processing Record 5 of Set 11 | shache
# Processing Record 6 of Set 11 | xiaoweizhai
# Processing Record 7 of Set 11 | kerema
# Processing Record 8 of Set 11 | szczytno
# Processing Record 9 of Set 11 | high rock
# Processing Record 10 of Set 11 | akonolinga
# Processing Record 11 of Set 11 | taltal
# Processing Record 12 of Set 11 | hualmay
# Processing Record 13 of Set 11 | yeppoon
# Processing Record 14 of Set 11 | kyra
# Processing Record 15 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 11 | san matias
# Processing Record 17 of Set 11 | ucluelet
# Processing Record 18 of Set 11 | tecolutla
# Processing Record 19 of Set 11 | shelburne
# Processing Record 20 of Set 11 | cayenne
# Processing Record 21 of Set 11 | sokoto
# Processing Record 22 of Set 11 | aleksandrovka
# Processing Record 23 of Set 11 | boden
# Processing Record 24 of Set 11 | yuanping
# Processing Record 25 of Set 11 | sindor
# Processing Record 26 of Set 11 | slave lake
# Processing Record 27 of Set 11 | praia da vitoria
# Processing Record 28 of Set 11 | zhenlai
# Processing Record 29 of Set 11 | palasbari
# Processing Record 30 of Set 11 | gizo
# Processing Record 31 of Set 11 | san andres
# Processing Record 32 of Set 11 | porto belo
# Processing Record 33 of Set 11 | anadyr
# Processing Record 34 of Set 11 | vestmannaeyjar
# Processing Record 35 of Set 11 | dharmabad
# Processing Record 36 of Set 11 | challans
# Processing Record 37 of Set 11 | taoudenni
# Processing Record 38 of Set 11 | geraldton
# Processing Record 39 of Set 11 | peyima
# Processing Record 40 of Set 11 | along
# Processing Record 41 of Set 11 | palmer
# Processing Record 42 of Set 11 | billund
# Processing Record 43 of Set 11 | olga
# Processing Record 44 of Set 11 | roald
# Processing Record 45 of Set 11 | douentza
# Processing Record 46 of Set 11 | henties bay
# Processing Record 47 of Set 11 | nhulunbuy
# Processing Record 48 of Set 11 | bonavista
# Processing Record 49 of Set 11 | dingle
# Processing Record 50 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 12 | tautira
# Processing Record 2 of Set 12 | allada
# Processing Record 3 of Set 12 | krasnyy chikoy
# Processing Record 4 of Set 12 | mbaiki
# Processing Record 5 of Set 12 | leningradskiy
# Processing Record 6 of Set 12 | coihaique
# Processing Record 7 of Set 12 | vila velha
# Processing Record 8 of Set 12 | shahpur chakar
# Processing Record 9 of Set 12 | kleck
# City not found. Skipping...
# Processing Record 10 of Set 12 | kieta
# Processing Record 11 of Set 12 | xai-xai
# Processing Record 12 of Set 12 | nola
# Processing Record 13 of Set 12 | port hedland
# Processing Record 14 of Set 12 | little current
# Processing Record 15 of Set 12 | iwanai
# Processing Record 16 of Set 12 | mangrol
# Processing Record 17 of Set 12 | batemans bay
# Processing Record 18 of Set 12 | pecos
# Processing Record 19 of Set 12 | arlit
# Processing Record 20 of Set 12 | natchez
# Processing Record 21 of Set 12 | egvekinot
# Processing Record 22 of Set 12 | otradnoye
# Processing Record 23 of Set 12 | farafangana
# Processing Record 24 of Set 12 | saint anthony
# Processing Record 25 of Set 12 | manuk mangkaw
# Processing Record 26 of Set 12 | chihuahua
# Processing Record 27 of Set 12 | japura
# Processing Record 28 of Set 12 | itoman
# Processing Record 29 of Set 12 | inndyr
# Processing Record 30 of Set 12 | pangnirtung
# Processing Record 31 of Set 12 | vuktyl
# Processing Record 32 of Set 12 | itacoatiara
# Processing Record 33 of Set 12 | djibo
# Processing Record 34 of Set 12 | yamada
# Processing Record 35 of Set 12 | tateyama
# Processing Record 36 of Set 12 | temiscaming
# Processing Record 37 of Set 12 | chimoio
# Processing Record 38 of Set 12 | the valley
# Processing Record 39 of Set 12 | okhotsk
# Processing Record 40 of Set 12 | san carlos de bariloche
# Processing Record 41 of Set 12 | bardiyah
# Processing Record 42 of Set 12 | kuala terengganu
# Processing Record 43 of Set 12 | uvarovka
# Processing Record 44 of Set 12 | petrozavodsk
# Processing Record 45 of Set 12 | xuzhou
# Processing Record 46 of Set 12 | plettenberg bay
# Processing Record 47 of Set 12 | rio gallegos
# Processing Record 48 of Set 12 | fort myers
# Processing Record 49 of Set 12 | husavik
# Processing Record 50 of Set 12 | los llanos de aridane
# Processing Record 1 of Set 13 | belmonte
# Processing Record 2 of Set 13 | termiz
# Processing Record 3 of Set 13 | talcahuano
# Processing Record 4 of Set 13 | haines junction
# Processing Record 5 of Set 13 | warrington
# Processing Record 6 of Set 13 | flinders
# Processing Record 7 of Set 13 | sambava
# Processing Record 8 of Set 13 | koungou
# Processing Record 9 of Set 13 | nisia floresta
# Processing Record 10 of Set 13 | chor
# Processing Record 11 of Set 13 | codrington
# Processing Record 12 of Set 13 | jalu
# Processing Record 13 of Set 13 | necochea
# Processing Record 14 of Set 13 | moose factory
# Processing Record 15 of Set 13 | sur
# Processing Record 16 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 17 of Set 13 | cozumel
# Processing Record 18 of Set 13 | richards bay
# Processing Record 19 of Set 13 | molokovo
# Processing Record 20 of Set 13 | dinsor
# City not found. Skipping...
# Processing Record 21 of Set 13 | burica
# City not found. Skipping...
# Processing Record 22 of Set 13 | mizpe ramon
# City not found. Skipping...
# Processing Record 23 of Set 13 | saint joseph
# Processing Record 24 of Set 13 | gladstone
# Processing Record 25 of Set 13 | nanortalik
# Processing Record 26 of Set 13 | cherskiy
# Processing Record 27 of Set 13 | carutapera
# Processing Record 28 of Set 13 | hami
# Processing Record 29 of Set 13 | novi ligure
# Processing Record 30 of Set 13 | glens falls
# Processing Record 31 of Set 13 | vejle
# Processing Record 32 of Set 13 | ternate
# Processing Record 33 of Set 13 | portland
# Processing Record 34 of Set 13 | falun
# Processing Record 35 of Set 13 | nouadhibou
# Processing Record 36 of Set 13 | bara
# Processing Record 37 of Set 13 | capelinha
# Processing Record 38 of Set 13 | tabulbah
# City not found. Skipping...
# Processing Record 39 of Set 13 | beipiao
# Processing Record 40 of Set 13 | corowa
# Processing Record 41 of Set 13 | tilichiki
# Processing Record 42 of Set 13 | sai buri
# Processing Record 43 of Set 13 | yar-sale
# Processing Record 44 of Set 13 | prince rupert
# Processing Record 45 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 46 of Set 13 | morondava
# Processing Record 47 of Set 13 | montgomery
# Processing Record 48 of Set 13 | negombo
# Processing Record 49 of Set 13 | bambanglipuro
# Processing Record 50 of Set 13 | sedelnikovo
# City not found. Skipping...
# Processing Record 1 of Set 14 | tanout
# Processing Record 2 of Set 14 | camacha
# Processing Record 3 of Set 14 | mvomero
# Processing Record 4 of Set 14 | mehran
# Processing Record 5 of Set 14 | angoche
# Processing Record 6 of Set 14 | kiruna
# Processing Record 7 of Set 14 | onega
# Processing Record 8 of Set 14 | itigi
# Processing Record 9 of Set 14 | mackay
# Processing Record 10 of Set 14 | lasa
# Processing Record 11 of Set 14 | bose
# Processing Record 12 of Set 14 | shaunavon
# Processing Record 13 of Set 14 | popondetta
# Processing Record 14 of Set 14 | hay river
# Processing Record 15 of Set 14 | petersburg
# Processing Record 16 of Set 14 | ubon ratchathani
# Processing Record 17 of Set 14 | lanzhou
# Processing Record 18 of Set 14 | novichikha
# Processing Record 19 of Set 14 | whyalla
# Processing Record 20 of Set 14 | muli
# Processing Record 21 of Set 14 | mitha tiwana
# Processing Record 22 of Set 14 | crixas
# Processing Record 23 of Set 14 | sandusky
# Processing Record 24 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 14 | druzhnaya gorka
# Processing Record 26 of Set 14 | bernay
# Processing Record 27 of Set 14 | port said
# Processing Record 28 of Set 14 | casas grandes
# Processing Record 29 of Set 14 | trincomalee
# Processing Record 30 of Set 14 | tsaratanana
# Processing Record 31 of Set 14 | riaba
# City not found. Skipping...
# Processing Record 32 of Set 14 | ouallam
# Processing Record 33 of Set 14 | christchurch
# Processing Record 34 of Set 14 | porto novo
# Processing Record 35 of Set 14 | rawlins
# Processing Record 36 of Set 14 | taft
# Processing Record 37 of Set 14 | tatawin
# Processing Record 38 of Set 14 | terrace
# Processing Record 39 of Set 14 | nioro
# Processing Record 40 of Set 14 | kloulklubed
# Processing Record 41 of Set 14 | merei
# Processing Record 42 of Set 14 | gagnoa
# Processing Record 43 of Set 14 | terrace bay
# Processing Record 44 of Set 14 | naryan-mar
# Processing Record 45 of Set 14 | lac du bonnet
# Processing Record 46 of Set 14 | tessalit
# Processing Record 47 of Set 14 | laguna
# Processing Record 48 of Set 14 | kirovsk
# Processing Record 49 of Set 14 | ustyuzhna
# Processing Record 50 of Set 14 | kailua
# Processing Record 1 of Set 15 | san jeronimo
# Processing Record 2 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 3 of Set 15 | yangjiang
# Processing Record 4 of Set 15 | bestobe
# Processing Record 5 of Set 15 | bandarbeyla
# Processing Record 6 of Set 15 | barra
# Processing Record 7 of Set 15 | inuvik
# Processing Record 8 of Set 15 | rognan
# Processing Record 9 of Set 15 | mildura
# Processing Record 10 of Set 15 | kasongo-lunda
# Processing Record 11 of Set 15 | damietta
# Processing Record 12 of Set 15 | ouagadougou
# Processing Record 13 of Set 15 | apiai
# Processing Record 14 of Set 15 | hovd
# Processing Record 15 of Set 15 | manaure
# Processing Record 16 of Set 15 | la reforma
# Processing Record 17 of Set 15 | muzaffarabad
# Processing Record 18 of Set 15 | ballina
# Processing Record 19 of Set 15 | margate
# Processing Record 20 of Set 15 | copiapo
# Processing Record 21 of Set 15 | shcholkine
# City not found. Skipping...
# Processing Record 22 of Set 15 | mogadishu
# Processing Record 23 of Set 15 | kidal
# Processing Record 24 of Set 15 | chabahar
# Processing Record 25 of Set 15 | bartica
# Processing Record 26 of Set 15 | blacksburg
# Processing Record 27 of Set 15 | donegal
# Processing Record 28 of Set 15 | kyabe
# Processing Record 29 of Set 15 | huangpi
# Processing Record 30 of Set 15 | patamundai
# Processing Record 31 of Set 15 | buala
# Processing Record 32 of Set 15 | samarai
# Processing Record 33 of Set 15 | imbituba
# Processing Record 34 of Set 15 | velky osek
# Processing Record 35 of Set 15 | plouzane
# Processing Record 36 of Set 15 | ekibastuz
# Processing Record 37 of Set 15 | nogliki
# Processing Record 38 of Set 15 | gollere
# City not found. Skipping...
# Processing Record 39 of Set 15 | bafata
# Processing Record 40 of Set 15 | gumdag
# Processing Record 41 of Set 15 | namie
# Processing Record 42 of Set 15 | tasbuget
# City not found. Skipping...
# Processing Record 43 of Set 15 | praia
# Processing Record 44 of Set 15 | murray bridge
# Processing Record 45 of Set 15 | varhaug
# Processing Record 46 of Set 15 | broken hill
# Processing Record 47 of Set 15 | kopavogur
# Processing Record 48 of Set 15 | bikin
# Processing Record 49 of Set 15 | ourinhos
# Processing Record 50 of Set 15 | yerofey pavlovich
# Processing Record 1 of Set 16 | karratha
# Processing Record 2 of Set 16 | lumberton
# Processing Record 3 of Set 16 | innisfail
# Processing Record 4 of Set 16 | vad
# Processing Record 5 of Set 16 | zanatepec
# City not found. Skipping...
# Processing Record 6 of Set 16 | alofi
# Processing Record 7 of Set 16 | atar
# Processing Record 8 of Set 16 | kargopol
# Processing Record 9 of Set 16 | yanan
# City not found. Skipping...
# Processing Record 10 of Set 16 | honggang
# Processing Record 11 of Set 16 | cockburn town
# Processing Record 12 of Set 16 | naze
# Processing Record 13 of Set 16 | hudson bay
# Processing Record 14 of Set 16 | nacala
# Processing Record 15 of Set 16 | springbok
# Processing Record 16 of Set 16 | czersk
# Processing Record 17 of Set 16 | keetmanshoop
# Processing Record 18 of Set 16 | saint simons
# Processing Record 19 of Set 16 | bull savanna
# Processing Record 20 of Set 16 | maua
# Processing Record 21 of Set 16 | port-gentil
# Processing Record 22 of Set 16 | panuco
# Processing Record 23 of Set 16 | tongsa
# City not found. Skipping...
# Processing Record 24 of Set 16 | velyka pysarivka
# Processing Record 25 of Set 16 | rawannawi
# City not found. Skipping...
# Processing Record 26 of Set 16 | soddy-daisy
# Processing Record 27 of Set 16 | bathsheba
# Processing Record 28 of Set 16 | tucuma
# Processing Record 29 of Set 16 | tarudant
# City not found. Skipping...
# Processing Record 30 of Set 16 | kansanshi
# Processing Record 31 of Set 16 | ostrovskoye
# Processing Record 32 of Set 16 | weyburn
# Processing Record 33 of Set 16 | gejiu
# Processing Record 34 of Set 16 | velikie luki
# City not found. Skipping...
# Processing Record 35 of Set 16 | lagoa
# Processing Record 36 of Set 16 | at-bashi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 722

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Nicolet      CA  46.2168  -72.6158     49.71        63           1
# 1    Hithadhoo      MV  -0.6000   73.0833     82.40        75         100
# 2        Udala      ES  43.0778   -2.5125     47.79        85          96
# 3    Inhambane      MZ -23.8650   35.3833     76.98        88          40
# 4     Westport      US  41.1415  -73.3579     54.99        48           1
# 5  Ulaanbaatar      MN  47.9077  106.8832     -7.47        71           0
# 6     Saldanha      ZA -33.0117   17.9442     62.65        69          99
# 7  San Antonio      US  29.4241  -98.4936     67.19        60           1
# 8  New Norfolk      AU -42.7826  147.0587     53.10        61          84
# 9  Port Alfred      ZA -33.5906   26.8910     63.36        81         100
#
#    Wind Speed Current Description
# 0       11.50           clear sky
# 1       13.24     overcast clouds
# 2        5.93     overcast clouds
# 3       10.36    scattered clouds
# 4        5.99           clear sky
# 5        2.24           clear sky
# 6       17.83     overcast clouds
# 7        3.44           clear sky
# 8        4.00       broken clouds
# 9        4.94     overcast clouds

# %%
output_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
